# %% [markdown]
# <a href="https://colab.research.google.com/github/agus476/proyecto-final-pp1--/blob/rama-agustin/proyecto_final_pp1_%F0%9F%8D%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
display("odio peru")
# Out:
# 'odio peru'
