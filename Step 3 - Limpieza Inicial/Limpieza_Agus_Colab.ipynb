# %%
# @title
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="es">
<head>
    <script src="https://cdn.tailwindcss.com"></script>
    <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600&family=Playfair+Display:ital,wght@0,600;0,700;1,600&display=swap" rel="stylesheet">
    <style>
        :root {
            --bg-academic: #060e24;
            --bg-card: #131c38;
            --accent-gold: #eab308;
            --text-main: #e2e8f0;
        }
        body { background-color: transparent; font-family: 'Inter', sans-serif; }

        .elite-container {
            max-width: 1100px;
            margin: 0 auto;
            background: linear-gradient(to bottom right, var(--bg-academic), #0a1433);
            color: var(--text-main);
            border-radius: 16px;
            padding: 48px;
            box-shadow: 0 25px 50px -12px rgba(0, 0, 0, 0.8);
            border: 1px solid #1e293b;
            position: relative;
            overflow: hidden;
        }

        .institutional-bg {
            position: absolute;
            top: 5%;
            left: 5%;
            width: 90%;
            height: 90%;
            opacity: 0.04;
            pointer-events: none;
            z-index: 0;
        }

        .content-relative { position: relative; z-index: 1; }

        .font-serif { font-family: 'Playfair Display', serif; }

        .neon-text-gold {
            text-shadow: 0 0 15px rgba(234, 179, 8, 0.4), 0 0 30px rgba(234, 179, 8, 0.2);
        }
        .neon-box-gold {
            box-shadow: 0 0 15px rgba(234, 179, 8, 0.25), inset 0 0 10px rgba(234, 179, 8, 0.15);
            border-color: rgba(234, 179, 8, 0.5);
        }

        .neon-text-emerald {
            text-shadow: 0 0 12px rgba(16, 185, 129, 0.5), 0 0 25px rgba(16, 185, 129, 0.2);
        }
        .neon-box-emerald {
            box-shadow: 0 0 20px rgba(16, 185, 129, 0.2), inset 0 0 15px rgba(16, 185, 129, 0.1);
            border-color: rgba(16, 185, 129, 0.6);
        }

        .dropcap::first-letter {
            float: left;
            font-size: 3.5rem;
            line-height: 0.8;
            padding-right: 0.5rem;
            padding-top: 0.2rem;
            color: var(--accent-gold);
            font-family: 'Playfair Display', serif;
            font-weight: bold;
            text-shadow: 0 0 12px rgba(234, 179, 8, 0.3);
        }

        .tab-btn {
            transition: all 0.3s cubic-bezier(0.4, 0, 0.2, 1);
            border-left: 4px solid transparent;
        }
        .tab-btn.active {
            background-color: #1e293b;
            border-left-color: var(--accent-gold);
            color: white;
            box-shadow: inset 0 2px 8px 0 rgba(0,0,0,0.2);
        }
        .tab-btn:hover:not(.active) {
            background-color: rgba(255,255,255,0.03);
            border-left-color: #475569;
        }
        .tab-content {
            display: none;
            animation: slideIn 0.4s ease-out forwards;
            opacity: 0;
            transform: translateX(10px);
        }
        .tab-content.active { display: block; }

        @keyframes slideIn {
            to { opacity: 1; transform: translateX(0); }
        }

        .badge-var {
            font-size: 0.7rem;
            text-transform: uppercase;
            letter-spacing: 0.05em;
            padding: 2px 8px;
            border-radius: 12px;
            border-width: 1px;
        }

        .chart-placeholder {
            background: repeating-linear-gradient(
                45deg,
                rgba(30, 41, 59, 0.3),
                rgba(30, 41, 59, 0.3) 10px,
                rgba(15, 23, 42, 0.3) 10px,
                rgba(15, 23, 42, 0.3) 20px
            );
            border: 1px dashed #334155;
            border-radius: 8px;
        }

        .kpi-card {
            transition: all 0.4s cubic-bezier(0.4, 0, 0.2, 1);
        }
        .kpi-card:hover {
            transform: translateY(-6px);
        }

        .team-card {
            background: rgba(15, 23, 42, 0.6);
            border: 1px solid #1e293b;
            border-radius: 16px;
            padding: 28px 20px 22px;
            display: flex;
            flex-direction: column;
            align-items: center;
            text-align: center;
            transition: all 0.4s cubic-bezier(0.4, 0, 0.2, 1);
            position: relative;
            overflow: hidden;
        }
        .team-card::before {
            content: '';
            position: absolute;
            top: 0; left: 0; right: 0;
            height: 3px;
            background: linear-gradient(90deg, transparent, var(--card-accent, #eab308), transparent);
            opacity: 0;
            transition: opacity 0.3s;
        }
        .team-card:hover {
            transform: translateY(-8px);
            border-color: var(--card-accent, #eab308);
            box-shadow: 0 16px 40px -12px rgba(0,0,0,0.6), 0 0 20px -4px var(--card-glow, rgba(234,179,8,0.2));
        }
        .team-card:hover::before { opacity: 1; }

        .avatar-ring {
            width: 80px;
            height: 80px;
            border-radius: 50%;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 2rem;
            margin-bottom: 14px;
            position: relative;
            border: 2px solid var(--card-accent, #eab308);
            background: radial-gradient(circle at 30% 30%, var(--avatar-bg1, #1e293b), var(--avatar-bg2, #0f172a));
            box-shadow: 0 0 18px -4px var(--card-glow, rgba(234,179,8,0.35));
            transition: box-shadow 0.3s, transform 0.3s;
        }
        .team-card:hover .avatar-ring {
            box-shadow: 0 0 28px -2px var(--card-glow, rgba(234,179,8,0.5));
            transform: scale(1.06);
        }

        .role-badge {
            font-size: 0.65rem;
            text-transform: uppercase;
            letter-spacing: 0.08em;
            padding: 3px 10px;
            border-radius: 20px;
            border-width: 1px;
            margin-top: 6px;
            margin-bottom: 10px;
        }

        .skill-pill {
            display: inline-block;
            font-size: 0.6rem;
            text-transform: uppercase;
            letter-spacing: 0.05em;
            padding: 2px 8px;
            border-radius: 10px;
            border: 1px solid #334155;
            background: rgba(30,41,59,0.6);
            color: #94a3b8;
            margin: 2px;
            transition: border-color 0.2s, color 0.2s;
        }
        .team-card:hover .skill-pill {
            border-color: var(--card-accent, #eab308);
            color: #e2e8f0;
        }

        .team-grid {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(170px, 1fr));
            gap: 18px;
        }
    </style>
</head>
<body>
    <div class="elite-container">

        <svg class="institutional-bg" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg">
            <path d="M 50 550 L 750 550 M 80 520 L 720 520 M 110 490 L 690 490" stroke="white" stroke-width="3" fill="none" />
            <rect x="150" y="250" width="40" height="240" stroke="white" stroke-width="2" fill="none"/>
            <rect x="280" y="250" width="40" height="240" stroke="white" stroke-width="2" fill="none"/>
            <rect x="410" y="250" width="40" height="240" stroke="white" stroke-width="2" fill="none"/>
            <rect x="540" y="250" width="40" height="240" stroke="white" stroke-width="2" fill="none"/>
            <rect x="670" y="250" width="40" height="240" stroke="white" stroke-width="2" fill="none"/>
            <path d="M 110 250 L 690 250 L 400 100 Z" stroke="white" stroke-width="3" fill="none" />
            <path d="M 160 230 L 640 230 L 400 130 Z" stroke="white" stroke-width="1.5" fill="none" />
        </svg>

        <div class="content-relative">
            <div class="flex flex-col md:flex-row justify-between items-start border-b border-slate-800 pb-8 mb-8">
                <div>
                    <div class="flex items-center gap-3 mb-4">
                        <span class="text-[10px] font-bold tracking-widest text-yellow-400 uppercase border border-yellow-500/50 px-3 py-1 rounded-full bg-yellow-500/10 neon-text-gold">
                            Preentrega Oficial
                        </span>
                        <span class="text-[10px] font-bold tracking-widest text-slate-400 uppercase border border-slate-700 px-3 py-1 rounded-full bg-slate-800/50">
                            Fase: Análisis Exploratorio
                        </span>
                    </div>
                    <h1 class="font-serif text-4xl md:text-5xl font-bold text-white leading-tight mb-3">
                        Dinámicas de Retención y <br><span class="text-yellow-500 neon-text-gold">Desgranamiento Escolar</span>
                    </h1>
                    <p class="text-slate-400 max-w-2xl text-sm leading-relaxed">
                        Modelado analítico basado en las bases del Relevamiento Anual educativo de Argentina.
                    </p>
                </div>

                <div class="hidden md:flex flex-col items-end gap-5 mt-4 md:mt-0">
                    <div class="opacity-90 p-4 bg-slate-800/60 rounded-2xl border neon-box-gold transition duration-500 hover:scale-105">
                        <svg width="56" height="56" viewBox="0 0 24 24" fill="none" stroke="#eab308" stroke-width="1.2" stroke-linecap="round" stroke-linejoin="round" style="filter: drop-shadow(0 0 4px rgba(234, 179, 8, 0.8));">
                            <path d="M22 10v6M2 10l10-5 10 5-10 5z"></path>
                            <path d="M6 12v5c3 3 9 3 12 0v-5"></path>
                        </svg>
                    </div>
                </div>
            </div>

            <div class="grid grid-cols-1 md:grid-cols-4 gap-4 mb-10">
                <div class="kpi-card bg-slate-900/50 border border-slate-800 p-4 rounded-xl flex items-center gap-4 hover:shadow-[0_8px_20px_rgba(59,130,246,0.15)] hover:border-blue-900/50">
                    <div class="p-3 bg-blue-500/10 rounded-lg text-blue-400">
                        <svg width="24" height="24" fill="none" stroke="currentColor" stroke-width="2"><path d="M4 6h16M4 10h16M4 14h16M4 18h16"></path></svg>
                    </div>
                    <div>
                        <p class="text-xs text-slate-500 uppercase tracking-wider">Volumen de Datos</p>
                        <p class="text-xl font-bold text-white">16.7K <span class="text-xs font-normal text-slate-400">filas</span></p>
                    </div>
                </div>
                <div class="kpi-card bg-slate-900/50 border border-slate-800 p-4 rounded-xl flex items-center gap-4 hover:shadow-[0_8px_20px_rgba(168,85,247,0.15)] hover:border-purple-900/50">
                    <div class="p-3 bg-purple-500/10 rounded-lg text-purple-400">
                        <svg width="24" height="24" fill="none" stroke="currentColor" stroke-width="2"><path d="M12 2v20M17 5H9.5a3.5 3.5 0 0 0 0 7h5a3.5 3.5 0 0 1 0 7H6"></path></svg>
                    </div>
                    <div>
                        <p class="text-xs text-slate-500 uppercase tracking-wider">Variables Base</p>
                        <p class="text-xl font-bold text-white">269 <span class="text-xs font-normal text-slate-400">features</span></p>
                    </div>
                </div>
                <div class="kpi-card bg-slate-900/50 border border-slate-800 p-4 rounded-xl flex items-center gap-4 hover:shadow-[0_8px_20px_rgba(244,63,94,0.15)] hover:border-rose-900/50">
                    <div class="p-3 bg-rose-500/10 rounded-lg text-rose-400">
                        <svg width="24" height="24" fill="none" stroke="currentColor" stroke-width="2"><path d="M15 14c.2-1 .7-1.7 1.5-2.5 1-.9 1.5-2.2 1.5-3.5A6 6 0 0 0 6 8c0 1 .2 2.2 1.5 3.5.7.7 1.3 1.5 1.5 2.5M9 18h6M10 22h4"></path></svg>
                    </div>
                    <div>
                        <p class="text-xs text-slate-500 uppercase tracking-wider">Hipótesis</p>
                        <p class="text-xl font-bold text-white">5 <span class="text-xs font-normal text-slate-400">evaluadas</span></p>
                    </div>
                </div>
                <div class="kpi-card bg-yellow-900/20 border neon-box-gold p-4 rounded-xl flex items-center gap-4 hover:shadow-[0_8px_25px_rgba(234,179,8,0.3)]">
                    <div class="p-3 bg-yellow-500/20 rounded-lg text-yellow-400">
                        <svg width="24" height="24" fill="none" stroke="currentColor" stroke-width="2" style="filter: drop-shadow(0 0 4px rgba(234, 179, 8, 0.8));"><path d="M12 8v4l3 3m6-3a9 9 0 11-18 0 9 9 0 0118 0z"></path></svg>
                    </div>
                    <div>
                        <p class="text-xs text-yellow-500 uppercase tracking-wider font-semibold neon-text-gold">Fase Actual</p>
                        <p class="text-xl font-bold text-yellow-400 neon-text-gold">EDA In Progress</p>
                    </div>
                </div>
            </div>

            <div class="mb-14">
                <h2 class="font-serif text-2xl font-bold text-white mb-6 border-l-4 border-yellow-500 pl-4 neon-text-gold" style="border-color: rgba(234,179,8,0.8); box-shadow: -4px 0 8px -4px rgba(234,179,8,0.6);">Abstract Ejecutivo</h2>
                <div class="bg-slate-900/40 p-8 rounded-xl border border-slate-800/80 shadow-inner">
                    <p class="dropcap text-slate-300 text-sm leading-relaxed mb-4 text-justify">
                        El presente proyecto describe un Análisis Exploratorio de Datos (EDA) sobre las bases del Relevamiento Anual educativo de Argentina. Su objetivo principal es identificar patrones que anticipen y expliquen la retención y el abandono escolar. Para lograrlo, el estudio adopta un enfoque práctico orientado a comprender las causas sistémicas detrás del desgranamiento estudiantil en los distintos niveles de formación.
                    </p>
                    <div class="grid md:grid-cols-2 gap-8 text-sm text-slate-400 leading-relaxed text-justify mt-6">
                        <div>
                            <p class="mb-4">
                                El análisis integra variables clave provenientes de tres ejes fundamentales: el flujo histórico del alumnado (matrícula y salidas sin pase), el perfil académico (índices de repitencia y sobreedad) y el contexto institucional (infraestructura y conectividad). Durante este proceso, se evalúan dimensiones críticas como la dependencia sectorial (gestión estatal frente a privada), la localización geográfica y las históricas diferencias entre los ámbitos urbanos y rurales.
                            </p>
                            <p>
                                Asimismo, el estudio profundiza en el perfil demográfico evaluando la brecha por sexo en relación con la continuidad escolar, y analiza cómo la interacción entre vulnerabilidad académica (alta sobreedad) y falta de recursos tecnológicos conforma escenarios de riesgo que desencadenan la deserción formal.
                            </p>
                        </div>
                        <div>
                            <p class="mb-4">
                                A nivel metodológico, la investigación aplica técnicas de limpieza, estructuración y preprocesamiento, incluyendo la verificación y tratamiento de valores nulos. Mediante el análisis multivariado y la creación de visualizaciones interactivas, se estudian las correlaciones entre los factores de gestión y demográficos, validando la capacidad del dataset para generar indicadores de alerta temprana.
                            </p>
                            <p class="p-4 bg-yellow-500/5 border border-yellow-500/30 rounded-lg text-slate-300 shadow-[inset_0_0_15px_rgba(234,179,8,0.05)]">
                                Finalmente, los hallazgos de esta etapa exploratoria sentarán las bases para la futura implementación de modelos de Machine Learning (ML). Al confirmar empíricamente que estas variables contienen señales predictivas, la siguiente fase buscará entrenar algoritmos capaces de perfilar instituciones en riesgo, optimizando la asignación estratégica de recursos.
                            </p>
                        </div>
                    </div>
                </div>
            </div>

            <div>
                <div class="mb-6">
                    <h2 class="font-serif text-2xl font-bold text-white border-l-4 border-yellow-500 pl-4 neon-text-gold" style="border-color: rgba(234,179,8,0.8); box-shadow: -4px 0 8px -4px rgba(234,179,8,0.6);">Dimensiones de Análisis</h2>
                    <p class="text-xs text-slate-400 mt-2 pl-5">Seleccione una dimensión para explorar su interrogante e hipótesis central.</p>
                </div>

                <div class="flex flex-col md:flex-row gap-8 bg-slate-900/30 rounded-xl border border-slate-800 p-2 overflow-hidden">

                    <div class="md:w-1/3 flex flex-col gap-1 mt-2">
                        <button class="tab-btn active text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-slate-400" onclick="openTab(event, 'h1')">
                            01. Tendencia Histórica
                        </button>
                        <button class="tab-btn text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-slate-400" onclick="openTab(event, 'h2')">
                            02. Brecha Sociodemográfica
                        </button>
                        <button class="tab-btn text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-slate-400" onclick="openTab(event, 'h3')">
                            03. Condición de Sobreedad
                        </button>
                        <button class="tab-btn text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-slate-400" onclick="openTab(event, 'h4')">
                            04. Infraestructura Escolar
                        </button>
                        <button class="tab-btn text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-emerald-400 mt-4 bg-emerald-900/20 neon-box-emerald neon-text-emerald" onclick="openTab(event, 'h5')">
                            🎯 Perfil de Riesgo (ML)
                        </button>

                        <div class="my-3 border-t border-slate-800/60"></div>

                        <button class="tab-btn text-left px-5 py-4 rounded-r-lg text-sm font-semibold text-slate-400" onclick="openTab(event, 'team')" style="--btn-accent: #a78bfa;">
                            👥 Nuestro Equipo
                        </button>
                    </div>

                    <div class="md:w-2/3 p-4">

                        <div id="h1" class="tab-content active bg-slate-800/40 rounded-xl p-8 border border-slate-700 h-full">
                            <div class="flex gap-2 mb-4">
                                <span class="badge-var bg-blue-900/30 text-blue-400 border-blue-800/50">Base: Trayectoria</span>
                                <span class="badge-var bg-blue-900/30 text-blue-400 border-blue-800/50">KPI: Salidas sin pase</span>
                            </div>
                            <h3 class="font-serif text-2xl text-white mb-4">La Tendencia Estructural</h3>
                            <div class="space-y-4">
                                <div>
                                    <span class="text-xs uppercase tracking-widest text-slate-500 font-bold">Pregunta</span>
                                    <p class="text-slate-300 text-sm mt-1 leading-relaxed">¿Se observa una mejora histórica sostenida en la capacidad de retención del sistema educativo a lo largo de la última década, o las tasas de abandono han llegado a una meseta?</p>
                                </div>
                                <div class="p-4 bg-slate-900/80 rounded-lg border-l-2 border-yellow-500" style="box-shadow: -2px 0 8px rgba(234,179,8,0.2);">
                                    <span class="text-xs uppercase tracking-widest text-yellow-500 font-bold">Hipótesis</span>
                                    <p class="text-slate-300 text-sm mt-1 italic leading-relaxed">Las tasas de salida sin pase muestran un estancamiento en los últimos anios, lo que indica que se necesitan herramientas predictivas (ML) para encontrar soluciones de retención focalizadas.</p>
                                </div>
                            </div>
                            <div class="mt-6 p-6 chart-placeholder flex flex-col items-center justify-center text-slate-500 h-40">
                                <svg width="32" height="32" fill="none" stroke="currentColor" stroke-width="1.5" class="mb-2 opacity-50"><path d="M18 20V10M12 20V4M6 20v-4"></path></svg>
                                <span class="text-xs tracking-widest uppercase font-semibold">Visualización de Evolución Histórica (Plotly)</span>
                            </div>
                        </div>

                        <div id="h2" class="tab-content bg-slate-800/40 rounded-xl p-8 border border-slate-700 h-full">
                            <div class="flex gap-2 mb-4">
                                <span class="badge-var bg-purple-900/30 text-purple-400 border-purple-800/50">Base: Trayectoria por sexo</span>
                                <span class="badge-var bg-purple-900/30 text-purple-400 border-purple-800/50">Variable: Género</span>
                            </div>
                            <h3 class="font-serif text-2xl text-white mb-4">La Brecha por Sexo</h3>
                            <div class="space-y-4">
                                <div>
                                    <span class="text-xs uppercase tracking-widest text-slate-500 font-bold">Pregunta</span>
                                    <p class="text-slate-300 text-sm mt-1 leading-relaxed">¿Existe una disparidad estructural en las tasas de retención y promoción entre varones y mujeres a medida que avanzan los anios de escolaridad?</p>
                                </div>
                                <div class="p-4 bg-slate-900/80 rounded-lg border-l-2 border-yellow-500" style="box-shadow: -2px 0 8px rgba(234,179,8,0.2);">
                                    <span class="text-xs uppercase tracking-widest text-yellow-500 font-bold">Hipótesis</span>
                                    <p class="text-slate-300 text-sm mt-1 italic leading-relaxed">Las estudiantes mujeres presentan de manera sostenida tasas de promoción superiores y menor índice de abandono que los varones, brecha que se amplía en los anios finales.</p>
                                </div>
                            </div>
                            <div class="mt-6 p-6 chart-placeholder flex flex-col items-center justify-center text-slate-500 h-40">
                                <svg width="32" height="32" fill="none" stroke="currentColor" stroke-width="1.5" class="mb-2 opacity-50"><path d="M12 20V10M18 20V4M6 20v-6"></path></svg>
                                <span class="text-xs tracking-widest uppercase font-semibold">Visualización Comparativa por Género (Plotly)</span>
                            </div>
                        </div>

                        <div id="h3" class="tab-content bg-slate-800/40 rounded-xl p-8 border border-slate-700 h-full">
                            <div class="flex gap-2 mb-4">
                                <span class="badge-var bg-orange-900/30 text-orange-400 border-orange-800/50">Base: Matrícula y secciones</span>
                                <span class="badge-var bg-orange-900/30 text-orange-400 border-orange-800/50">Variable: Sobreedad</span>
                            </div>
                            <h3 class="font-serif text-2xl text-white mb-4">El Peso de la Sobreedad</h3>
                            <div class="space-y-4">
                                <div>
                                    <span class="text-xs uppercase tracking-widest text-slate-500 font-bold">Pregunta</span>
                                    <p class="text-slate-300 text-sm mt-1 leading-relaxed">¿Qué nivel de correlación existe entre la tasa de alumnos con sobreedad en un establecimiento y su respectivo índice de abandono?</p>
                                </div>
                                <div class="p-4 bg-slate-900/80 rounded-lg border-l-2 border-yellow-500" style="box-shadow: -2px 0 8px rgba(234,179,8,0.2);">
                                    <span class="text-xs uppercase tracking-widest text-yellow-500 font-bold">Hipótesis</span>
                                    <p class="text-slate-300 text-sm mt-1 italic leading-relaxed">La sobreedad actúa como el predictor académico más fuerte de deserción; las institutions con alta concentración de alumnos en esta condición duplican sus tasas de salidas sin pase.</p>
                                </div>
                            </div>
                            <div class="mt-6 p-6 chart-placeholder flex flex-col items-center justify-center text-slate-500 h-40">
                                <svg width="32" height="32" fill="none" stroke="currentColor" stroke-width="1.5" class="mb-2 opacity-50"><path d="M12 20V10M18 20V4M6 20v-6"></path></svg>
                                <span class="text-xs tracking-widest uppercase font-semibold">Scatter Plot: Correlación Sobreedad vs Abandono</span>
                            </div>
                        </div>

                        <div id="h4" class="tab-content bg-slate-800/40 rounded-xl p-8 border border-slate-700 h-full">
                            <div class="flex gap-2 mb-4">
                                <span class="badge-var bg-cyan-900/30 text-cyan-400 border-cyan-800/50">Base: Características</span>
                                <span class="badge-var bg-cyan-900/30 text-cyan-400 border-cyan-800/50">Cruce: Ámbito Rural + Internet</span>
                            </div>
                            <h3 class="font-serif text-2xl text-white mb-4">La Infraestructura como Ancla</h3>
                            <div class="space-y-4">
                                <div>
                                    <span class="text-xs uppercase tracking-widest text-slate-500 font-bold">Pregunta</span>
                                    <p class="text-slate-300 text-sm mt-1 leading-relaxed">En contextos de alta vulnerabilidad (ámbitos rurales estatales), ¿disponer de conectividad en las aulas funciona como un factor protector que reduce la deserción?</p>
                                </div>
                                <div class="p-4 bg-slate-900/80 rounded-lg border-l-2 border-yellow-500" style="box-shadow: -2px 0 8px rgba(234,179,8,0.2);">
                                    <span class="text-xs uppercase tracking-widest text-yellow-500 font-bold">Hipótesis</span>
                                    <p class="text-slate-300 text-sm mt-1 italic leading-relaxed">Las escuelas rurales que cuentan con internet y equipamiento logran retener un porcentaje significativamente mayor de alumnos que aquellas sin acceso, mitigando la brecha geográfica.</p>
                                </div>
                            </div>
                            <div class="mt-6 p-6 chart-placeholder flex flex-col items-center justify-center text-slate-500 h-40">
                                <svg width="32" height="32" fill="none" stroke="currentColor" stroke-width="1.5" class="mb-2 opacity-50"><path d="M12 20V10M18 20V4M6 20v-6"></path></svg>
                                <span class="text-xs tracking-widest uppercase font-semibold">Boxplot: Retención por Nivel de Conectividad</span>
                            </div>
                        </div>

                        <div id="h5" class="tab-content bg-slate-900/80 rounded-xl p-8 neon-box-emerald h-full">
                            <div class="flex gap-2 mb-4">
                                <span class="badge-var bg-emerald-900/40 text-emerald-300 border-emerald-500/50 shadow-[0_0_10px_rgba(16,185,129,0.2)]">Proyección Fase 2</span>
                                <span class="badge-var bg-emerald-900/40 text-emerald-300 border-emerald-500/50 shadow-[0_0_10px_rgba(16,185,129,0.2)]">Clustering</span>
                            </div>
                            <h3 class="font-serif text-2xl text-emerald-400 mb-4 neon-text-emerald">El Perfil de Riesgo Institucional</h3>
                            <div class="space-y-4">
                                <div>
                                    <span class="text-xs uppercase tracking-widest text-emerald-500 font-bold">Pregunta</span>
                                    <p class="text-slate-300 text-sm mt-1 leading-relaxed">Combinando factores académicos e institucionales, ¿cuál es el perfil exacto de los establecimientos con mayor riesgo de pérdida de matrícula?</p>
                                </div>

                                <div class="p-5 bg-emerald-900/20 rounded-xl border neon-box-emerald flex flex-col gap-1 mt-4 transition-all duration-300 hover:-translate-y-1">
                                    <span class="text-xs uppercase tracking-widest text-emerald-400 font-bold neon-text-emerald">Hipótesis de Riesgo Crítico</span>
                                    <p class="text-emerald-100/90 text-sm mt-1 italic leading-relaxed font-medium">El riesgo máximo de abandono se concentra en un clúster específico: escuelas de gestión estatal, en ámbito rural, con falta de conectividad y alta tasa previa de sobreedad y repitencia.</p>
                                </div>

                            </div>
                            <div class="mt-6 p-6 chart-placeholder border-emerald-800/50 flex flex-col items-center justify-center text-emerald-600/70 h-40" style="background: repeating-linear-gradient(45deg, rgba(6, 78, 59, 0.15), rgba(6, 78, 59, 0.15) 10px, rgba(2, 44, 34, 0.15) 10px, rgba(2, 44, 34, 0.15) 20px);">
                                <svg width="32" height="32" fill="none" stroke="currentColor" stroke-width="1.5" class="mb-2 opacity-60" style="filter: drop-shadow(0 0 4px rgba(16, 185, 129, 0.5));"><path d="M21 16V8a2 2 0 0 0-1-1.73l-7-4a2 2 0 0 0-2 0l-7 4A2 2 0 0 0 3 8v8a2 2 0 0 0 1 1.73l7 4a2 2 0 0 0 2 0l7-4A2 2 0 0 0 21 16z"></path></svg>
                                <span class="text-xs tracking-widest uppercase font-semibold text-emerald-500 neon-text-emerald">Heatmap de Correlación Multivariable</span>
                            </div>
                        </div>

                        <div id="team" class="tab-content bg-slate-900/60 rounded-xl p-8 border border-slate-700/60 h-full">

                            <div class="flex items-center gap-3 mb-2">
                                <span class="badge-var bg-violet-900/40 text-violet-300 border-violet-500/50">Equipo</span>
                                <span class="badge-var bg-violet-900/40 text-violet-300 border-violet-500/50">Pistacho 🍈</span>
                            </div>
                            <h3 class="font-serif text-2xl text-white mb-1">Las personas detrás del análisis</h3>
                            <p class="text-slate-500 text-xs mb-8 leading-relaxed">Un equipo multidisciplinario unido por la convicción de que los datos pueden transformar la educación.</p>

                            <div class="team-grid">

                                <div class="team-card" style="--card-accent:#f472b6; --card-glow:rgba(244,114,182,0.3); --avatar-bg1:#2d0a1e; --avatar-bg2:#1a0512;">
                                    <div class="avatar-ring" style="border-color:#f472b6;">🎨</div>
                                    <p class="text-white font-semibold text-sm">María Eugenia</p>
                                    <p class="text-slate-500 text-xs -mt-1 mb-1">Rodríguez</p>
                                    <span class="role-badge bg-pink-900/30 text-pink-300 border border-pink-500/40">Viz & UX</span>
                                    <div class="flex flex-wrap justify-center gap-1 mt-1">
                                        <span class="skill-pill">Plotly</span>
                                        <span class="skill-pill">Diseño</span>
                                        <span class="skill-pill">HTML</span>
                                    </div>
                                </div>

                                <div class="team-card" style="--card-accent:#fb923c; --card-glow:rgba(251,146,60,0.3); --avatar-bg1:#431407; --avatar-bg2:#1c0a00;">
                                    <div class="avatar-ring" style="border-color:#fb923c;">🧪</div>
                                    <p class="text-white font-semibold text-sm">Francisco Gastón</p>
                                    <p class="text-slate-500 text-xs -mt-1 mb-1">Amaya</p>
                                    <span class="role-badge bg-orange-900/30 text-orange-300 border border-orange-500/40">Tester</span>
                                    <div class="flex flex-wrap justify-center gap-1 mt-1">
                                        <span class="skill-pill">QA</span>
                                        <span class="skill-pill">Validación</span>
                                        <span class="skill-pill">Testing</span>
                                    </div>
                                </div>

                                <div class="team-card" style="--card-accent:#38bdf8; --card-glow:rgba(56,189,248,0.3); --avatar-bg1:#0c1a2e; --avatar-bg2:#050f1c;">
                                    <div class="avatar-ring" style="border-color:#38bdf8;">📊</div>
                                    <p class="text-white font-semibold text-sm">Walter</p>
                                    <p class="text-slate-500 text-xs -mt-1 mb-1">Chavez</p>
                                    <span class="role-badge bg-sky-900/30 text-sky-300 border border-sky-500/40">Data Analyst</span>
                                    <div class="flex flex-wrap justify-center gap-1 mt-1">
                                        <span class="skill-pill">EDA</span>
                                        <span class="skill-pill">Pandas</span>
                                        <span class="skill-pill">Estadística</span>
                                    </div>
                                </div>

                                <div class="team-card" style="--card-accent:#34d399; --card-glow:rgba(52,211,153,0.3); --avatar-bg1:#022c22; --avatar-bg2:#011a14;">
                                    <div class="avatar-ring" style="border-color:#34d399;">🗄️</div>
                                    <p class="text-white font-semibold text-sm">Ramiro</p>
                                    <p class="text-slate-500 text-xs -mt-1 mb-1">Sadlovsky</p>
                                    <span class="role-badge bg-emerald-900/30 text-emerald-300 border border-emerald-500/40">DB Engineer</span>
                                    <div class="flex flex-wrap justify-center gap-1 mt-1">
                                        <span class="skill-pill">Bases de datos</span>
                                        <span class="skill-pill">SQL</span>
                                        <span class="skill-pill">ETL</span>
                                    </div>
                                </div>

                                <div class="team-card" style="--card-accent:#a78bfa; --card-glow:rgba(167,139,250,0.3); --avatar-bg1:#2e1065; --avatar-bg2:#1e1b4b;">
                                    <div class="avatar-ring" style="border-color:#a78bfa;">🧭</div>
                                    <p class="text-white font-semibold text-sm">Agustín</p>
                                    <p class="text-slate-500 text-xs -mt-1 mb-1">Sanchez</p>
                                    <span class="role-badge bg-violet-900/30 text-violet-300 border border-violet-500/40">Project Manager</span>
                                    <div class="flex flex-wrap justify-center gap-1 mt-1">
                                        <span class="skill-pill">Coordinación</span>
                                        <span class="skill-pill">Docs</span>
                                        <span class="skill-pill">Presentación</span>
                                    </div>
                                </div>

                            </div>

                            <div class="mt-10 p-5 bg-violet-900/10 border border-violet-500/20 rounded-xl text-center" style="box-shadow: inset 0 0 20px rgba(167,139,250,0.05);">
                                <p class="text-violet-300/80 text-xs italic leading-relaxed">
                                    "Somos un equipo que combina curiosidad estadística, sensibilidad social y pasión por los datos —<br>porque detrás de cada fila del dataset hay una trayectoria estudiantil que importa."
                                </p>
                                <div class="flex justify-center gap-2 mt-4 flex-wrap">
                                    <span class="badge-var bg-slate-800 text-slate-400 border-slate-700">Python 🐍</span>
                                    <span class="badge-var bg-slate-800 text-slate-400 border-slate-700">Jupyter 📓</span>
                                    <span class="badge-var bg-slate-800 text-slate-400 border-slate-700">Plotly 📊</span>
                                    <span class="badge-var bg-slate-800 text-slate-400 border-slate-700">Sklearn 🤖</span>
                                    <span class="badge-var bg-slate-800 text-slate-400 border-slate-700">Pandas 🐼</span>
                                </div>
                            </div>
                        </div>
                        </div>
                </div>
            </div>

            <div style="text-align: center; margin-top: 80px; padding-top: 30px; border-top: 1px solid rgba(255,255,255,0.1);">
                <p class="font-georgia italic text-slate-500 text-sm mb-4">"La educación es el único algoritmo capaz de transformar el futuro de una nación"</p>
                <div style="font-size: 10px; letter-spacing: 3px; color: #475569; text-transform: uppercase;">Argentina &middot; Pistacho team 🍈 &middot; 2026</div>
            </div>
        </div>
    </div>

    <script>
        function openTab(evt, tabId) {
            let tabContents = document.getElementsByClassName("tab-content");
            for (let i = 0; i < tabContents.length; i++) {
                tabContents[i].classList.remove("active");
            }
            let tabBtns = document.getElementsByClassName("tab-btn");
            for (let i = 0; i < tabBtns.length; i++) {
                tabBtns[i].classList.remove("active");
            }
            document.getElementById(tabId).classList.add("active");
            evt.currentTarget.classList.add("active");
        }
    </script>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <script src="https://cdn.tailwindcss.com"></script>
#     <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600&family=Playfair+Display:ital,wght@0,600;0,700;1,600&display=swap" rel="stylesheet">
#     <style>
#         :root {
#             --bg-academic: #060e24;
#             --bg-card: #131c38;
#             --accent-gold: #eab308;
#             --text-main: #e2e8f0;
#         }
#         body { background-color: transparent; font-family: 'Inter', sans-serif; }
#
#         .elite-container {
#             max-width: 1100px;
#             margin: 0 auto;
#             background: linear-gradient(to bottom right, var(--bg-academic), #0a1433);
#             color: var(--text-main);
#             border-radius: 16px;
#             padding: 48px;
#             box-shadow: 0 25px 50px -12px rgba(0, 0, 0, 0.8);
#             border: 1px solid #1e293b;
#             position: relative;
# ...

# %%
#WALTER EL EXCEL DE MATRICULA POR SECCION TIENE QUE QUEDAR ASI

import pandas as pd
from google.colab import drive


drive.mount('/content/drive')



path = '/content/drive/MyDrive/PP1/matricula_y_secciones_final.csv'

df = pd.read_csv(path)
#print(*df.columns, sep='\n')

df = df.drop(columns=['lactantes','deambulantes','s2','s3','s4','s5','_snu','v_lactantes','v_deambulantes',
'v_s2',
'v_s3',
'v_s4',
'v_s5',
'v_snu',
's_lactantes',
's_deambulantes',
's_s2',
's_s3',
's_s4',
's_s5',
'_seclactantes',
'_secdeambu',
'_secs2',
'_secs3',
'_secs4',
'_secs5',
'_sec1',
'_sec2',
'_sec3',
'_sec4',
'_sec5',
'_sec6',
'_sec7',
'_sec8',
'_sec9',
'_sec10',
'_sec11',
'_sec12',
'_sec1314',
'multi_ini',
'multi_pri',
'multi_sec',
'multinivel'])




nuevos_nombres = {
    'provincia': 'provincia',
    'departamento': 'departamento',
    'sector': 'sector',
    'ambito': 'ambito'
}

for i in range(1, 13):
    # Definimos el sufijo: del 1 al 5 es "grado", del 6 al 12 es "anio"
    if i <= 6:
        etiqueta = f'grado_{i}'
    else:
        # 6 es 1er anio, 7 es 2do anio, etc.
        etiqueta = f'anio_{i-6}'

    nuevos_nombres[f'_{i}'] = f'total_{etiqueta}'
    nuevos_nombres[f'v_{i}'] = f'varones_{etiqueta}'
    nuevos_nombres[f'r_{i}'] = f'repitentes_{etiqueta}'
    nuevos_nombres[f's_{i}'] = f'sobreedad_{etiqueta}'

# Casos especiales (13 y 14 suelen ser anios superiores)
nuevos_nombres.update({
    '_1314': 'total_anio_sup', 'v_1314': 'varones_anio_sup',
    'r_1314': 'repitentes_anio_sup', 's_1314': 'sobreedad_anio_sup'
})

df = df.rename(columns=nuevos_nombres)

# 2. Convertir a numérico (Indispensable para calcular)
# Seleccionamos todas las columnas excepto las 4 de texto iniciales
cols_a_convertir = df.columns.drop(['provincia', 'departamento', 'sector', 'ambito'])
for col in cols_a_convertir:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# 3. Cálculos de Mujeres, Tasas de Repitencia y Sobreedad
for i in range(1, 13):
    if i <= 6:
        e = f'grado_{i}'
    else:
        e = f'anio_{i-6}'

    # Crear columna de Mujeres
    df[f'mujeres_{e}'] = df[f'total_{e}'] - df[f'varones_{e}']

    # Tasa de Repitencia (Repitentes / Total * 100)
    # Usamos .replace(0, 1) en el denominador para evitar división por cero
    df[f'tasa_repitencia_{e}'] = (df[f'repitentes_{e}'] / df[f'total_{e}'].replace(0, 1)) * 100

    # Tasa de Sobreedad (Sobreedad / Total * 100)
    df[f'tasa_sobreedad_{e}'] = (df[f'sobreedad_{e}'] / df[f'total_{e}'].replace(0, 1)) * 100

# Verificamos los nuevos cálculos para el primer grado
#display(df[['total_grado_5', 'varones_grado_5', 'mujeres_grado_5', 'tasa_repitencia_grado_5']].head())

display(df.info())

# ==============================
# 💾 Guardar dataset matrícula limpio
# ==============================

import os

output_path = '/content/drive/MyDrive/datasets_limpios'
os.makedirs(output_path, exist_ok=True)

df.to_excel(f'{output_path}/matricula_limpia.xlsx', index=False)

print("✅ Matrícula guardada correctamente")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16803 entries, 0 to 16802
# Data columns (total 93 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   anio                     16803 non-null  int64
#  1   provincia                16803 non-null  object
#  2   departamento             16803 non-null  object
#  3   sector                   16803 non-null  object
#  4   ambito                   16803 non-null  object
#  5   total_grado_1            16803 non-null  int64
#  6   total_grado_2            16803 non-null  int64
#  7   total_grado_3            16803 non-null  int64
#  8   total_grado_4            16803 non-null  int64
#  9   total_grado_5            16803 non-null  int64
#  10  total_grado_6            16803 non-null  int64
# ...

# %%
import pandas as pd
import unicodedata

path = '/content/drive/MyDrive/PP1/caracteristicas_del_establecimiento_final.csv'

df = pd.read_csv(path)

# ==============================
# 🧹 LIMPIAR NOMBRES DE COLUMNAS
# ==============================

def limpiar_texto(texto):
    return ''.join(
        c for c in unicodedata.normalize('NFKD', texto)
        if not unicodedata.combining(c)
    )

df.columns = [limpiar_texto(col) for col in df.columns]

# ==============================
# 🗑️ DROP
# ==============================

df = df.drop(columns=[
'EquipamientoEstablecimientoTelevisor',
'EquipamientoEstablecimientoSistemamultimediaoCanon',
'EquipamientoEstablecimientoScanner',
'EquipamientoEstablecimientoWebcam',
'EquipamientoEstablecimientoReproductordeCD',
'EquipamientoEstablecimientoReproductordeDVD',
'EquipamientoEstablecimientoImpresora',
'EquipamientoEstablecimientoEquipoemisorderadioAMFM',
'EquipamientoEstablecimientoEquiporeceptorderadioAMFM',
'EquipamientoEstablecimientoServidorparausoescolar',
'EquipamientoEstablecimientoImpresora3D',
'EquipamientoEstablecimientoEquipodeSonido',
'EquipamientoEstablecimientoPizarrasdigitales'
], errors='ignore')

# ==============================
# 🔍 VALIDACIÓN
# ==============================

print("Columnas finales:", len(df.columns))
display(df.info())

# ==============================
# 💾 GUARDADO
# ==============================

df.to_excel(f'{output_path}/caracteristicas_limpio.xlsx', index=False)

print("✅ Características guardado correctamente")
# Out:
# Columnas finales: 66
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16804 entries, 0 to 16803
# Data columns (total 66 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   anio                                                  16804 non-null  int64
#  1   provincia                                             16804 non-null  object
#  2   departamento                                          16804 non-null  object
#  3   sector                                                16804 non-null  object
#  4   ambito                                                16804 non-null  object
#  5   localizacion                                          16804 non-null  int64
#  6   electricidadsi                                        16804 non-null  object
#  7   electricidadredpublica                                16804 non-null  object
# ...

# %%
import pandas as pd

path = '/content/drive/MyDrive/PP1/trayectoria_por_sexo_final.csv'

# ==============================
# 📥 CARGA CORRECTA
# ==============================

df = pd.read_csv(path)  # <-- SIN sep=';'

# ==============================
# 🧹 DROP (robusto)
# ==============================

df = df.drop(columns=[
'entrados_1','entrados_2','entrados_3','entrados_4','entrados_5','entrados_6',
'entrados_7','entrados_8','entrados_9','entrados_10','entrados_11','entrados_12','entrados_1314',
'm_entrados_1','m_entrados_2','m_entrados_3','m_entrados_4','m_entrados_5','m_entrados_6',
'm_entrados_7','m_entrados_8','m_entrados_9','m_entrados_10','m_entrados_11','m_entrados_12','m_entrados_1314',
'scp_1','scp_2','scp_3','scp_4','scp_5','scp_6','scp_7','scp_8','scp_9','scp_10','scp_11','scp_12','scp_1314',
'm_scp_1','m_scp_2','m_scp_3','m_scp_4','m_scp_5','m_scp_6','m_scp_7','m_scp_8','m_scp_9','m_scp_10','m_scp_11','m_scp_12','m_scp_1314',
'regulares_1','regulares_2','regulares_3','regulares_4','regulares_5','regulares_6','regulares_7','regulares_8',
'regulares_9','regulares_10','regulares_11','regulares_12','regulares_1314',
'm_regulares_1','m_regulares_2','m_regulares_3','m_regulares_4','m_regulares_5','m_regulares_6',
'm_regulares_7','m_regulares_8','m_regulares_9','m_regulares_10','m_regulares_11','m_regulares_12','m_regulares_1314',
'otros_1','otros_2','otros_3','otros_4','otros_5','otros_6','otros_7','otros_8','otros_9','otros_10','otros_11','otros_12','otros_1314',
'm_otros_1','m_otros_2','m_otros_3','m_otros_4','m_otros_5','m_otros_6','m_otros_7','m_otros_8','m_otros_9','m_otros_10','m_otros_11','m_otros_12','m_otros_1314'
], errors='ignore')

# ==============================
# 🔄 RENOMBRE (lo tuyo está bien)
# ==============================

nuevos_nombres = {
    'provincia': 'provincia',
    'departamento': 'departamento',
    'sector': 'sector',
    'ambito': 'ambito',
    'primaria_egresados': 'egresados_primaria',
    'primaria_m_egresados': 'egresados_mujeres_primaria',
    'secundaria_egresados': 'egresados_secundaria',
    'secundaria_m_egresados': 'egresados_mujeres_secundaria'
}

# (mantengo tu lógica porque está BIEN 👌)
dic_prefijos = {
    'inicial_': 'inscritos_marzo_',
    'm_inicial_': 'inscritos_marzo_mujeres_',
    'ssp_': 'desercion_',
    'm_ssp_': 'desercion_mujeres_',
    'ultimo_': 'alumnos_diciembre_',
    'm_ultimo_': 'alumnos_diciembre_mujeres_',
    'promovidos_': 'aprobados_',
    'm_promovidos_': 'aprobados_mujeres_',
    'promovidos_ex_': 'aprobados_mesas_',
    'm_promovidos_ex_': 'aprobados_mesas_mujeres_',
    'nopromo_': 'reprobados_',
    'm_nopromo_': 'reprobados_mujeres_'
}

for i in range(1, 13):
    etiqueta = f'grado_{i}' if i <= 6 else f'anio_{i-6}'
    for original, intuitivo in dic_prefijos.items():
        nuevos_nombres[f'{original}{i}'] = f'{intuitivo}{etiqueta}'

for original, intuitivo in dic_prefijos.items():
    nuevos_nombres[f'{original}1314'] = f'{intuitivo}anio_superior'

df = df.rename(columns=nuevos_nombres)

# ==============================
# 🔢 NUMÉRICOS
# ==============================

cols_base = ['provincia', 'departamento', 'sector', 'ambito']
cols_numericas = df.columns.drop(cols_base)
df[cols_numericas] = df[cols_numericas].apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)

# ==============================
# 💾 GUARDADO
# ==============================

df.to_excel(f'{output_path}/trayectoria_limpia.xlsx', index=False)

print("✅ Trayectoria guardada correctamente")
# Out:
# ✅ Trayectoria guardada correctamente
