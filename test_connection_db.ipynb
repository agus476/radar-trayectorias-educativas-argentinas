# %% [markdown]
# <a href="https://colab.research.google.com/github/agus476/proyecto-final-pp1--/blob/branch-ramiro/test_connection_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import duckdb as db
import pandas as pd
conn = db.connect('etl_pistacho.duckdb')

conn.execute(f"""
    CREATE OR REPLACE TABLE prueba1 AS
    SELECT *
    FROM read_csv_auto('/content/productos.csv',
                       delim='|',
                       header=true,
                       quote='"',
                       escape='"',
                       encoding='utf-8',
                       ignore_errors=true)
""")

# %%
display(conn.execute("""SELECT DISTINCT productos_unidad_medida_referencia FROM prueba1 """).fetchdf())
# Out:
#   productos_unidad_medida_referencia
# 0                                 kg
# 1                             unidad
